# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from ctypes import *
import os
import platform

# %%
#Function of conversion of list of list to simple list 
def toList(arr):
    return [j for i in arr for j in i]

# %%
#
path_to_shared_library = "target/debug/librust_lib.dylib"
path_to_shared_library_windows = "target\\debug\\rust_lib.dll"

if(platform.system()=='Windows'):
    my_lib = cdll.LoadLibrary(path_to_shared_library_windows)
else : 
    my_lib = cdll.LoadLibrary(path_to_shared_library)

# %% [markdown]
# # Cas de tests, rendu 2

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Linear Simple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %% [markdown]
# #### Linear Model :

# %%
#Dataset
X= np.array([
      [1, 1],
      [2, 3],
      [3, 3]
])
Y= np.array([
      1,
      -1,
      -1
])


#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y.tolist()
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs )


#Declaration of argtypes and restypes for the function create_model
my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

#Creation of model
arr_size = 2
native_arr = my_lib.create_model(arr_size)

arr_size += 1

#Declaration of argtypes and restypes for the function train_rosenblatt_linear_model
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 2
my_lib.predict_linear_model_classification.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_classification.restype = c_float


#Trainning
r = np.arange(0.0, 4.0, 0.25)

for _ in range(100):
    points_x1_blue = []
    points_x2_blue = []

    points_x1_red = []
    points_x2_red = []

    for i in r:
        for j in r:
            coord = coordonate_type(*[i, j])
            res=my_lib.predict_linear_model_classification(native_arr, coord,arr_size,inputs_len)
            if  res> 0.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            else:
                points_x1_red.append(i)
                points_x2_red.append(j)

    
    if(_%10==0):
        plt.scatter(points_x1_blue, points_x2_blue, c='blue')
        plt.scatter(points_x1_red, points_x2_red, c='red')
        
        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]>0], [X[p][1] for p in range(len(Y)) if Y[p]>0], c='blue', s=100)
        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]<0], [X[p][1] for p in range(len(Y)) if Y[p]<0], c='red', s=100)

        plt.show()
        plt.clf()

    dataset_inputs_for_train = []
    for elt in X:
        dataset_inputs_for_train.append(elt[0])
        dataset_inputs_for_train.append(elt[1])

    #update model
    my_lib.train_rosenblatt_linear_model(native_arr, inputs_native, outputs_native, 20, 0.001, arr_size, inputs_len,expected_len)    
    np_arr = np.ctypeslib.as_array(native_arr, (arr_size,))

#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
#Dataset
X= np.array([
      [2.5, 3.5],
      [2, 3],
      [3, 3]
])
Y= np.array([
      1,
      -1,
      -1
])

d=[2,1]

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y.tolist()
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)


#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p


model = my_lib.create_mlp_model(native_arr,2)
test_dataset = [[x1/10, x2 / 10] for x1 in range(-10, 40,2) for x2 in range(-10, 40,2)]
colors = ["blue" if output >= 0 else "red" for output in dataset_expected_outputs]


#Declaration of argtypes and restypes for the function predict_mlp_model_classification
p_type = c_float*2
my_lib.predict_mlp_model_classification.argtypes = [c_void_p, p_type,c_int]
my_lib.predict_mlp_model_classification.restype = POINTER(c_float)
p_len =2

predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=200)
plt.show()


flattened_len=len(dataset_inputs)
#Declaration of argtypes and restypes for the function predict_mlp_model_classification
inputs_type = c_float * flattened_len
outputs_type = c_float * expected_len
my_lib.train_classification_stochastic_backdrop_mlp_model.argtypes = [c_void_p,inputs_type,outputs_type,c_float,c_int,c_int,c_int]
my_lib.train_classification_stochastic_backdrop_mlp_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

my_lib.train_classification_stochastic_backdrop_mlp_model(model,inputs_native,outputs_native,0.001,100000,flattened_len,expected_len)


predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=200)
plt.show()


#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(X[0, 0], X[0, 1], color='blue')
plt.scatter(X[1:3,0], X[1:3,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Multiple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %% [markdown]
# #### Linear model

# %%
#Dataset
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])


#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs )


#Declaration of argtypes and restypes for the function create_model
my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

#Creation of model
arr_size = 2
native_arr = my_lib.create_model(arr_size)

arr_size += 1
#Declaration of argtypes and restypes for the function train_rosenblatt_linear_model
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 2
my_lib.predict_linear_model_classification.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_classification.restype = c_float


#Trainning
r = np.arange(0.5, 3.5, 0.2)

for _ in range(100):
    points_x1_blue = []
    points_x2_blue = []

    points_x1_red = []
    points_x2_red = []

    for i in r:
        for j in r:
            coord = coordonate_type(*[i, j])
            res=my_lib.predict_linear_model_classification(native_arr, coord,arr_size,inputs_len)
            if  res> 0.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            else:
                points_x1_red.append(i)
                points_x2_red.append(j)

    if(_%10==0):        
        plt.scatter(points_x1_blue, points_x2_blue, c='blue')
        plt.scatter(points_x1_red, points_x2_red, c='red')

        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]>0], [X[p][1] for p in range(len(Y)) if Y[p]>0], c='blue', s=100)
        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]<0], [X[p][1] for p in range(len(Y)) if Y[p]<0], c='red', s=100)

        plt.show()
        plt.clf()

    dataset_inputs_for_train = []
    for elt in X:
        dataset_inputs_for_train.append(elt[0])
        dataset_inputs_for_train.append(elt[1])

    #update model
    my_lib.train_rosenblatt_linear_model(native_arr, inputs_native, outputs_native, 10000, 0.001, arr_size, inputs_len,expected_len)    

    
#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
#Dataset
X = np.concatenate([np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

d=[2,1]

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)


#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p


model = my_lib.create_mlp_model(native_arr,2)
test_dataset = [[x1/10, x2 / 10] for x1 in range(5, 35,2) for x2 in range(5, 35,2)]
colors = ["blue" if output >= 0 else "red" for output in dataset_expected_outputs]


#Declaration of argtypes and restypes for the function predict_mlp_model_classification
p_type = c_float*2
my_lib.predict_mlp_model_classification.argtypes = [c_void_p, p_type,c_int]
my_lib.predict_mlp_model_classification.restype = POINTER(c_float)
p_len =2

predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=100)
plt.show()


flattened_len=len(dataset_inputs)
#Declaration of argtypes and restypes for the function predict_mlp_model_classification
inputs_type = c_float * flattened_len
outputs_type = c_float * expected_len
my_lib.train_classification_stochastic_backdrop_mlp_model.argtypes = [c_void_p,inputs_type,outputs_type,c_float,c_int,c_int,c_int]
my_lib.train_classification_stochastic_backdrop_mlp_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

my_lib.train_classification_stochastic_backdrop_mlp_model(model,inputs_native,outputs_native,0.001,100000,flattened_len,expected_len)


predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=100)
plt.show()


    #Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### XOR :
#         Linear Model    : KO
#         MLP (2, 2, 1)   : OK
#
#         Gaussienne : ?

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %% [markdown]
# #### Linear model

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y.tolist()
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs )


#Declaration of argtypes and restypes for the function create_model
my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

#Creation of model
arr_size = 2
native_arr = my_lib.create_model(arr_size)

arr_size += 1
#Declaration of argtypes and restypes for the function train_rosenblatt_linear_model
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 2
my_lib.predict_linear_model_classification.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_classification.restype = c_float


#Trainning
r = np.arange(0.0, 1.25, 0.1)

for _ in range(100):
    points_x1_blue = []
    points_x2_blue = []

    points_x1_red = []
    points_x2_red = []

    for i in r:
        for j in r:
            coord = coordonate_type(*[i, j])
            res=my_lib.predict_linear_model_classification(native_arr, coord,arr_size,inputs_len)
            if  res> 0.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            else:
                points_x1_red.append(i)
                points_x2_red.append(j)

    
    if(_%10==0):
        plt.scatter(points_x1_blue, points_x2_blue, c='blue')
        plt.scatter(points_x1_red, points_x2_red, c='red')
        
        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]>0], [X[p][1] for p in range(len(Y)) if Y[p]>0], c='blue', s=100)
        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]<0], [X[p][1] for p in range(len(Y)) if Y[p]<0], c='red', s=100)

        plt.show()
        plt.clf()

    dataset_inputs_for_train = []
    for elt in X:
        dataset_inputs_for_train.append(elt[0])
        dataset_inputs_for_train.append(elt[1])

    #update model
    my_lib.train_rosenblatt_linear_model(native_arr, inputs_native, outputs_native, 20, 0.001, arr_size, inputs_len,expected_len)    
    np_arr = np.ctypeslib.as_array(native_arr, (arr_size,))

#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### Perceptron transformation linéaire

# %%
dataset_input = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
dataset_expected_outputs_xor = np.array([1, 1, -1, -1])
dataset_expected_outputs_or = np.array([1,1,-1,1])
dataset_expected_outputs_nand = np.array([1,1,1,-1])
dataset_expected_outputs_and = np.array([-1,-1,-1,1])

dataset_inputs  = toList(dataset_input)
dataset_expected_outputs_or  = dataset_expected_outputs_or.tolist()
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs_or)

my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)
model_size = 2

model_xor = my_lib.create_model(model_size)
model_or = my_lib.create_model(model_size)
model_nand = my_lib.create_model(model_size)
model_and = my_lib.create_model(model_size)

test_dataset = [[x1/10, x2 / 10] for x1 in range(-5, 15,2) for x2 in range(-5,15,2)]
colors = ["blue" if output >= 0 else "red" for output in dataset_expected_outputs_xor]

#to show the initial points we have
model_type = type(model_xor)
inputs_size = 2
inputs_type = c_float * inputs_size
my_lib.predict_linear_model_classification.argtypes = [model_type, inputs_type,c_int, c_int]
my_lib.predict_linear_model_classification.restype = c_float

predicted_outputs = [my_lib.predict_linear_model_classification(model_xor, inputs_type(*p), (model_size+1), inputs_size)  for p in test_dataset]
predicted_outputs_colors = ['blue' if label == 1 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in dataset_input], [p[1] for p in dataset_input], c=colors, s=200)
plt.show()

#train the models
arr_type = type(model_or)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None

inputs_native = inputs_type(*dataset_inputs)
my_lib.train_rosenblatt_linear_model(model_or, inputs_native, outputs_type(*dataset_expected_outputs_or), 400000, 0.001, (model_size+1), inputs_len,expected_len)
my_lib.train_rosenblatt_linear_model(model_nand, inputs_native, outputs_type(*dataset_expected_outputs_nand), 400000, 0.001, (model_size+1), inputs_len,expected_len)
my_lib.train_rosenblatt_linear_model(model_and, inputs_native, outputs_type(*dataset_expected_outputs_and), 400000, 0.001, (model_size+1), inputs_len,expected_len)

#outputs
inputs_size = 2
inputs_type = c_float * inputs_size
predicted_outputs = []
for p in test_dataset:
    or_res = my_lib.predict_linear_model_classification(model_or, inputs_type(*p), (model_size+1),inputs_size)
    nand_res = my_lib.predict_linear_model_classification(model_nand, inputs_type(*p), (model_size+1),inputs_size)
    res = my_lib.predict_linear_model_classification(model_and, inputs_type(*[or_res,nand_res]), (model_size+1),inputs_size)
    predicted_outputs.append(res)

predicted_outputs_colors = ['blue' if label == 1 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in dataset_input], [p[1] for p in dataset_input], c=colors, s=100)
plt.show()
#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(model_xor, (model_size+1))
my_lib.destroy_array(model_or, (model_size+1))
my_lib.destroy_array(model_nand, (model_size+1))
my_lib.destroy_array(model_and, (model_size+1))

# %% [markdown]
# #### MLP

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])
d=[2,2,1]

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)


#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p


model = my_lib.create_mlp_model(native_arr,arr_size)
test_dataset = [[x1/10, x2 / 10] for x1 in range(-5, 15,2) for x2 in range(-5,15,2)]
colors = ["blue" if output >= 0 else "red" for output in dataset_expected_outputs]


#Declaration of argtypes and restypes for the function predict_mlp_model_classification
p_type = c_float*2
my_lib.predict_mlp_model_classification.argtypes = [c_void_p, p_type,c_int]
my_lib.predict_mlp_model_classification.restype = POINTER(c_float)
p_len =2

predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=100)
plt.show()

flattened_dataset_inputs = []
for p in X:
  flattened_dataset_inputs.append(p[0])
  flattened_dataset_inputs.append(p[1])


flattened_len=len(flattened_dataset_inputs )
#Declaration of argtypes and restypes for the function predict_mlp_model_classification
inputs_type = c_float * flattened_len
outputs_type = c_float * expected_len
my_lib.train_classification_stochastic_backdrop_mlp_model.argtypes = [c_void_p,inputs_type,outputs_type,c_float,c_int,c_int,c_int]
my_lib.train_classification_stochastic_backdrop_mlp_model.restype = None
inputs_native = inputs_type(*flattened_dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

my_lib.train_classification_stochastic_backdrop_mlp_model(model,inputs_native,outputs_native,0.001,100000,flattened_len,expected_len)


predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=100)
plt.show()

    
#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Cross :
#         Linear Model    : KO
#         MLP (2, 4, 1)   : OK

# %% [markdown]
# #### Linear model

# %%
#Dataset
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs )


#Declaration of argtypes and restypes for the function create_model
my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

#Creation of model
arr_size = 2
native_arr = my_lib.create_model(arr_size)
arr_size+=1

#Declaration of argtypes and restypes for the function train_rosenblatt_linear_model
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 2
my_lib.predict_linear_model_classification.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_classification.restype = c_float


#Trainning
r = np.arange(-1.0, 1.0, 0.1)

for _ in range(100):
    points_x1_blue = []
    points_x2_blue = []

    points_x1_red = []
    points_x2_red = []

    for i in r:
        for j in r:
            coord = coordonate_type(*[i, j])
            res=my_lib.predict_linear_model_classification(native_arr, coord,arr_size,inputs_len)
            if  res> 0.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            else:
                points_x1_red.append(i)
                points_x2_red.append(j)

    if(_%10==0):        
        plt.scatter(points_x1_blue, points_x2_blue, c='blue')
        plt.scatter(points_x1_red, points_x2_red, c='red')

        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]>0], [X[p][1] for p in range(len(Y)) if Y[p]>0], c='blue', s=60)
        plt.scatter([X[p][0] for p in range(len(Y)) if Y[p]<0], [X[p][1] for p in range(len(Y)) if Y[p]<0], c='red', s=60)

        plt.show()
        plt.clf()

    dataset_inputs_for_train = []
    for elt in X:
        dataset_inputs_for_train.append(elt[0])
        dataset_inputs_for_train.append(elt[1])

    #update model
    my_lib.train_rosenblatt_linear_model(native_arr, inputs_native, outputs_native, 50, 0.001, arr_size, inputs_len,expected_len)    
    np_arr = np.ctypeslib.as_array(native_arr, (arr_size,))

    
#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

d=[2,4,1]

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)


#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p


model = my_lib.create_mlp_model(native_arr,len(d))
test_dataset = [[x1 / 10, x2 / 10] for x1 in range(-10, 10) for x2 in range(-10, 10)]
colors = ["blue" if output >= 0 else "red" for output in dataset_expected_outputs]


#Declaration of argtypes and restypes for the function predict_mlp_model_classification
p_type = c_float*2
my_lib.predict_mlp_model_classification.argtypes = [c_void_p, p_type,c_int]
my_lib.predict_mlp_model_classification.restype = POINTER(c_float)
p_len =2

predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=50)
plt.show()

flattened_len=len(dataset_inputs)
#Declaration of argtypes and restypes for the function predict_mlp_model_classification
inputs_type = c_float * flattened_len
outputs_type = c_float * expected_len
my_lib.train_classification_stochastic_backdrop_mlp_model.argtypes = [c_void_p,inputs_type,outputs_type,c_float,c_int,c_int,c_int]
my_lib.train_classification_stochastic_backdrop_mlp_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

my_lib.train_classification_stochastic_backdrop_mlp_model(model,inputs_native,outputs_native,0.001,300000,flattened_len,expected_len)


predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),p_len)[0] for p in test_dataset]
predicted_outputs_colors = ['blue' if label >= 0 else 'red' for label in predicted_outputs]
plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
#plt.scatter([p[0] for p in X], [p[1] for p in X], c=colors, s=50)
plt.show()
    
#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Multi Linear 3 classes :
#         Linear Model x3 : OK
#         MLP (2, 3)      : OK

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
              [0, 0, 0]for p in X])

# %% [markdown]
# #### Linear model

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
             [0, 0, 0]for p in X])

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = [1 if i==1 else -1 for i in Y[:,0]]
dataset_expected_outputs2  =[1 if i==1 else -1 for i in Y[:,1]]
dataset_expected_outputs3  =[1 if i==1 else -1 for i in Y[:,2]]
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)


#Declaration of argtypes and restypes for the function create_model
my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

#Creation of model
arr_size = 2
native_arr_blue = my_lib.create_model(arr_size)
native_arr_red = my_lib.create_model(arr_size)
native_arr_green = my_lib.create_model(arr_size)
arr_size +=1

#Declaration of argtypes and restypes for the function train_rosenblatt_linear_model
arr_type = type(native_arr_blue)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native_blue = outputs_type(*dataset_expected_outputs)
outputs_native_red = outputs_type(*dataset_expected_outputs2)
outputs_native_green = outputs_type(*dataset_expected_outputs3)

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 2
my_lib.predict_linear_model_classification.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_classification.restype = c_float


#Trainning
r = np.arange(-1.0, 1.1, 0.1)

for _ in range(100):
    points_x1_blue = []
    points_x2_blue = []

    points_x1_no_blue = []
    points_x2_no_blue = []
    
    points_x1_red = []
    points_x2_red= []

    points_x1_no_red = []
    points_x2_no_red = []
    
    points_x1_green = []
    points_x2_green = []

    points_x1_no_green = []
    points_x2_no_green = []
    
        
    for i in r:
        for j in r:
            coord = coordonate_type(*[i, j])
            if  my_lib.predict_linear_model_classification(native_arr_blue, coord,arr_size,inputs_len)> 0.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            else:
                points_x1_no_blue.append(i)
                points_x2_no_blue.append(j)
                
            if  my_lib.predict_linear_model_classification(native_arr_red, coord,arr_size,inputs_len)>0.0:
                points_x1_red.append(i)
                points_x2_red.append(j)
            else:
                points_x1_no_red.append(i)
                points_x2_no_red.append(j)
            
            if  my_lib.predict_linear_model_classification(native_arr_green, coord,arr_size,inputs_len)> 0.0:
                points_x1_green.append(i)
                points_x2_green.append(j)
            else:
                points_x1_no_green.append(i)
                points_x2_no_green.append(j)
                
    if(_==99):        
        plt.scatter(points_x1_blue, points_x2_blue, c='blue')
        plt.scatter(points_x1_no_blue, points_x2_no_blue, c='purple')

        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')

        plt.show()
        plt.clf()
        
                
        plt.scatter(points_x1_red, points_x2_red, c='red')
        plt.scatter(points_x1_no_red, points_x2_no_red, c='purple')

        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')

        plt.show()
        plt.clf()
        
        plt.scatter(points_x1_green, points_x2_green, c='green')
        plt.scatter(points_x1_no_green, points_x2_no_green, c='purple')

        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')

        plt.show()
        plt.clf()



    dataset_inputs_for_train = []
    for elt in X:
        dataset_inputs_for_train.append(elt[0])
        dataset_inputs_for_train.append(elt[1])

    #update model
    my_lib.train_rosenblatt_linear_model(native_arr_blue, inputs_native, outputs_native_blue, 50, 0.001, arr_size, inputs_len,expected_len)    
    my_lib.train_rosenblatt_linear_model(native_arr_red, inputs_native, outputs_native_red, 50, 0.001, arr_size, inputs_len,expected_len)
    my_lib.train_rosenblatt_linear_model(native_arr_green, inputs_native, outputs_native_green, 50, 0.001, arr_size, inputs_len,expected_len)

    
#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr_blue, arr_size)
my_lib.destroy_array(native_arr_red, arr_size)
my_lib.destroy_array(native_arr_green, arr_size)


plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue',s=100)
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red',s=100)
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green',s=100)

plt.scatter(points_x1_blue, points_x2_blue, c='blue')
plt.scatter(points_x1_red, points_x2_red, c='red')
plt.scatter(points_x1_green, points_x2_green, c='green')
plt.show()
plt.clf()

# %% [markdown]
# #### MLP

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else 
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else 
              [0, 0, 0]for p in X])

dataset_inputs = X
dataset_expected_outputs = Y
d = [2, 3]


#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p

model = my_lib.create_mlp_model(native_arr,arr_size)
test_dataset = [[x1 / 10, x2 / 10] for x1 in range(-10, 10) for x2 in range(-10, 10)]
colors = ["blue" if np.argmax(output) == 0 else ("red" if np.argmax(output) == 1 else "green") for output in dataset_expected_outputs]

p_type = c_float * 2
my_lib.predict_mlp_model_classification.argtypes =[c_void_p,p_type,c_int]
my_lib.predict_mlp_model_classification.restype = POINTER(c_float)

#predicted_outputs = [my_lib.predict_mlp_model_classification(model, p_type(*p),len(p))[0] for p in test_dataset]
predicted_outputs = []
for p in test_dataset:
    prediction = my_lib.predict_mlp_model_classification(model, p_type(*p),len(p))
    prediction = np.ctypeslib.as_array(prediction, (3,))
    predicted_outputs.append(prediction.tolist())

predicted_outputs_colors = ["blue" if np.argmax(output) == 0 else ("red" if np.argmax(output) == 1 else "green") for output in predicted_outputs]

plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in dataset_inputs], [p[1] for p in dataset_inputs], c=colors, s=50)
plt.show()

flattened_dataset_inputs = []
for p in dataset_inputs:
  flattened_dataset_inputs.append(p[0])
  flattened_dataset_inputs.append(p[1])

flattened_dataset_outputs = []
for p in dataset_expected_outputs:
  flattened_dataset_outputs.append(p[0])
  flattened_dataset_outputs.append(p[1])
  flattened_dataset_outputs.append(p[2])

flattened_dataset_input_type = c_float * len(flattened_dataset_inputs)
flattened_dataset_output_type = c_float * len(flattened_dataset_outputs)

my_lib.train_classification_stochastic_backdrop_mlp_model.argtypes = [c_void_p, flattened_dataset_input_type, flattened_dataset_output_type, c_float, c_int, c_int, c_int]
my_lib.train_classification_stochastic_backdrop_mlp_model.restype = None

my_lib.train_classification_stochastic_backdrop_mlp_model(model, flattened_dataset_input_type(*flattened_dataset_inputs), flattened_dataset_output_type(*flattened_dataset_outputs), 0.01, 100000, len(flattened_dataset_inputs), len(flattened_dataset_outputs))

predicted_outputs = []
for p in test_dataset:
    prediction = my_lib.predict_mlp_model_classification(model, p_type(*p),len(p))
    prediction = np.ctypeslib.as_array(prediction, (3,))
    predicted_outputs.append(prediction.tolist())

predicted_outputs_colors = ["blue" if np.argmax(output) == 0 else ("red" if np.argmax(output) == 1 else "green") for output in predicted_outputs]

plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in dataset_inputs], [p[1] for p in dataset_inputs], c=colors, s=50)
plt.show()

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ### Multi Cross :
#         Linear Model x3 : KO
#         MLP (2, ?, ?, 3): OK
#
#         lloyd?

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

# %% [markdown]
# #### Linear model

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = [1 if i==1 else -1 for i in Y[:,0]]
dataset_expected_outputs2  =[1 if i==1 else -1 for i in Y[:,1]]
dataset_expected_outputs3  =[1 if i==1 else -1 for i in Y[:,2]]
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)


#Declaration of argtypes and restypes for the function create_model
my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

#Creation of model
arr_size = 2
native_arr_blue = my_lib.create_model(arr_size)
native_arr_red = my_lib.create_model(arr_size)
native_arr_green = my_lib.create_model(arr_size)
arr_size +=1

#Declaration of argtypes and restypes for the function train_rosenblatt_linear_model
arr_type = type(native_arr_blue)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_rosenblatt_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_float, c_int, c_int,c_int]
my_lib.train_rosenblatt_linear_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native_blue = outputs_type(*dataset_expected_outputs)
outputs_native_red = outputs_type(*dataset_expected_outputs2)
outputs_native_green = outputs_type(*dataset_expected_outputs3)

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 2
my_lib.predict_linear_model_classification.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_classification.restype = c_float


#Trainning
r = np.arange(-1.0, 1.1, 0.1)

for _ in range(100):
    points_x1_blue = []
    points_x2_blue = []

    points_x1_no_blue = []
    points_x2_no_blue = []
    
    points_x1_red = []
    points_x2_red= []

    points_x1_no_red = []
    points_x2_no_red = []
    
    points_x1_green = []
    points_x2_green = []

    points_x1_no_green = []
    points_x2_no_green = []
    
        
    for i in r:
        for j in r:
            coord = coordonate_type(*[i, j])
            if  my_lib.predict_linear_model_classification(native_arr_blue, coord,arr_size,inputs_len)> 0.0:
                points_x1_blue.append(i)
                points_x2_blue.append(j)
            else:
                points_x1_no_blue.append(i)
                points_x2_no_blue.append(j)
                
            if  my_lib.predict_linear_model_classification(native_arr_red, coord,arr_size,inputs_len)>0.0:
                points_x1_red.append(i)
                points_x2_red.append(j)
            else:
                points_x1_no_red.append(i)
                points_x2_no_red.append(j)
            
            if  my_lib.predict_linear_model_classification(native_arr_green, coord,arr_size,inputs_len)> 0.0:
                points_x1_green.append(i)
                points_x2_green.append(j)
            else:
                points_x1_no_green.append(i)
                points_x2_no_green.append(j)
                
    if(_==99):        
        plt.scatter(points_x1_blue, points_x2_blue, c='blue')
        plt.scatter(points_x1_no_blue, points_x2_no_blue, c='purple')

        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')

        plt.show()
        plt.clf()
        
                
        plt.scatter(points_x1_red, points_x2_red, c='red')
        plt.scatter(points_x1_no_red, points_x2_no_red, c='purple')

        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')

        plt.show()
        plt.clf()
        
        plt.scatter(points_x1_green, points_x2_green, c='green')
        plt.scatter(points_x1_no_green, points_x2_no_green, c='purple')

        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
        plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')

        plt.show()
        plt.clf()



    dataset_inputs_for_train = []
    for elt in X:
        dataset_inputs_for_train.append(elt[0])
        dataset_inputs_for_train.append(elt[1])

    #update model
    my_lib.train_rosenblatt_linear_model(native_arr_blue, inputs_native, outputs_native_blue, 50, 0.001, arr_size, inputs_len,expected_len)    
    my_lib.train_rosenblatt_linear_model(native_arr_red, inputs_native, outputs_native_red, 50, 0.001, arr_size, inputs_len,expected_len)
    my_lib.train_rosenblatt_linear_model(native_arr_green, inputs_native, outputs_native_green, 50, 0.001, arr_size, inputs_len,expected_len)

    
#Free memory
my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr_blue, arr_size)
my_lib.destroy_array(native_arr_red, arr_size)
my_lib.destroy_array(native_arr_green, arr_size)


plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue',s=100)
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red',s=100)
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green',s=100)

plt.scatter(points_x1_blue, points_x2_blue, c='blue')
plt.scatter(points_x1_red, points_x2_red, c='red')
plt.scatter(points_x1_green, points_x2_green, c='green')
plt.show()
plt.clf()

# %% [markdown]
# #### MLP

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [0, 1, 0] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [0, 0, 1] for p in X])

dataset_inputs = X
dataset_expected_outputs = Y

d = [2, 30, 30, 3]


#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p

model = my_lib.create_mlp_model(native_arr,arr_size)
test_dataset = [[x1 / 10, x2 / 10] for x1 in range(-10, 11) for x2 in range(-10, 11)]
colors = ["blue" if np.argmax(output) == 0 else ("red" if np.argmax(output) == 1 else "green") for output in dataset_expected_outputs]

p_type = c_float * 2
my_lib.predict_mlp_model_classification.argtypes =[c_void_p,p_type,c_int]
my_lib.predict_mlp_model_classification.restype = POINTER(c_float)

predicted_outputs = []
for p in test_dataset:
    prediction = my_lib.predict_mlp_model_classification(model, p_type(*p),len(p))
    prediction = np.ctypeslib.as_array(prediction, (3,))
    predicted_outputs.append(prediction.tolist())

predicted_outputs_colors = ["blue" if np.argmax(output) == 0 else ("red" if np.argmax(output) == 1 else "green") for output in predicted_outputs]

plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
plt.scatter([p[0] for p in dataset_inputs], [p[1] for p in dataset_inputs], c=colors, s=50)
plt.show()

flattened_dataset_inputs = []
for p in dataset_inputs:
  flattened_dataset_inputs.append(p[0])
  flattened_dataset_inputs.append(p[1])

flattened_dataset_outputs = []
for p in dataset_expected_outputs:
  flattened_dataset_outputs.append(p[0])
  flattened_dataset_outputs.append(p[1])
  flattened_dataset_outputs.append(p[2])

flattened_dataset_input_type = c_float * len(flattened_dataset_inputs)
flattened_dataset_output_type = c_float * len(flattened_dataset_outputs)

my_lib.train_classification_stochastic_backdrop_mlp_model.argtypes = [c_void_p, flattened_dataset_input_type, flattened_dataset_output_type, c_float, c_int, c_int, c_int]
my_lib.train_classification_stochastic_backdrop_mlp_model.restype = None

my_lib.train_classification_stochastic_backdrop_mlp_model(model, flattened_dataset_input_type(*flattened_dataset_inputs), flattened_dataset_output_type(*flattened_dataset_outputs), 0.01, 1000000, len(flattened_dataset_inputs), len(flattened_dataset_outputs))

predicted_outputs = []
for p in test_dataset:
    prediction = my_lib.predict_mlp_model_classification(model, p_type(*p),len(p))
    prediction = np.ctypeslib.as_array(prediction, (3,))
    predicted_outputs.append(prediction.tolist())

predicted_outputs_colors = ["blue" if np.argmax(output) == 0 else ("red" if np.argmax(output) == 1 else "green") for output in predicted_outputs]

plt.scatter([p[0] for p in test_dataset], [p[1] for p in test_dataset], c=predicted_outputs_colors)
#plt.scatter([p[0] for p in dataset_inputs], [p[1] for p in dataset_inputs], c=colors, s=50)
plt.show()

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ## Régression

# %% [markdown]
# ### Linear Simple 2D :
#         Linear Model : OK
#         MLP (1, 1)   : OK

# %% [markdown]
# #### Linear model

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      2,
      3
])

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

arr_size = 1
native_arr = my_lib.create_model(arr_size)

arr_size += 1

inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordinate_type = c_float * 1
my_lib.predict_linear_model_regression.argtypes = [arr_type, coordinate_type, c_int,c_int]
my_lib.predict_linear_model_regression.restype = c_float


plt.axis([-10, 10, -10, 10])
test_dataset = [[i] for i in range (-10,11)]
predicted_outputs = [my_lib.predict_linear_model_regression(native_arr,coordinate_type(*point),arr_size,len(point)) for point in test_dataset]

plt.scatter(test_dataset, predicted_outputs)
plt.scatter(dataset_inputs, dataset_expected_outputs, c="purple")
plt.show()

my_lib.train_regression_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_int, c_int, c_int, c_int]
my_lib.train_regression_linear_model.restype =None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)
inputs_dim = len(X[0])
outputs_dim = 1


my_lib.train_regression_linear_model(native_arr, inputs_native, outputs_native, arr_size,inputs_len,expected_len, inputs_dim, outputs_dim)
np_arr = np.ctypeslib.as_array(native_arr, (arr_size,))


plt.axis([-10, 10, -10, 10])
predicted_outputs = [my_lib.predict_linear_model_regression(native_arr,coordinate_type(*point),arr_size,len(point)) for point in test_dataset]

plt.scatter(test_dataset, predicted_outputs)
plt.scatter(dataset_inputs, dataset_expected_outputs, c="purple")
plt.show()



my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
X = np.array([
      [1],
      [2]
])
Y = np.array([
      2,
      3
])

d=[1,1]

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y.tolist()
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)

#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p

#creation of the model
model = my_lib.create_mlp_model(native_arr,arr_size)
test_dataset_inputs = [i for i in range(-10, 11)]

#declaration of the predict
f = c_float * 1
my_lib.predict_mlp_model_regression.argtypes = [c_void_p, f,c_int]
my_lib.predict_mlp_model_regression.restype = POINTER(c_float)
coordinate_len =1

#get the predicted outputs without training
predicted_outputs = [my_lib.predict_mlp_model_regression(model, f(*[point]), 1)[0] for point in test_dataset_inputs]

#plot the result
plt.plot(test_dataset_inputs, predicted_outputs)
plt.scatter([p for p in dataset_inputs], dataset_expected_outputs, s=200, color='purple')
plt.axis([-10, 10, -10, 10])
plt.show()


#Declaration of argtypes and restypes for the function predict_mlp_model_regression
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_regression_stochastic_backdrop_mlp_model.argtypes = [c_void_p,inputs_type,outputs_type,c_float,c_int,c_int,c_int]
my_lib.train_regression_stochastic_backdrop_mlp_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

my_lib.train_regression_stochastic_backdrop_mlp_model(model,inputs_native,outputs_native,0.001,100000,inputs_len,expected_len)


predicted_outputs = [my_lib.predict_mlp_model_regression(model, f(*[point]), 1)[0] for point in test_dataset_inputs]

plt.plot(test_dataset_inputs, predicted_outputs)
plt.scatter([p for p in dataset_inputs], dataset_expected_outputs, s=200, color='purple')
plt.axis([-10, 10, -10, 10])
plt.show()

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 2D :
#         Linear Model    : OK
#         MLP (1, ?, 1)   : OK

# %% [markdown]
# #### Linear model

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

arr_size = 1
native_arr = my_lib.create_model(arr_size)
arr_size += 1
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordonate_type = c_float * 1
my_lib.predict_linear_model_regression.argtypes = [arr_type, coordonate_type, c_int,c_int]
my_lib.predict_linear_model_regression.restype = c_float


points_x = []
points_y = []
plt.axis([-10, 10, -10, 10])
for i in range(-10, 11):
    points_x.append(i)
    point=[i]
    coord = coordonate_type(*point)
    points_y.append(my_lib.predict_linear_model_regression(native_arr,coord ,arr_size,inputs_len))

plt.scatter(points_x, points_y)
plt.scatter(dataset_inputs, dataset_expected_outputs, c="purple")
plt.show()

my_lib.train_regression_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int,c_int, c_int, c_int, c_int]
my_lib.train_regression_linear_model.restype =None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

input_dim = len(X[0])
output_dim = 1

my_lib.train_regression_linear_model(native_arr, inputs_native, outputs_native, arr_size,inputs_len, expected_len, input_dim,output_dim)

points_x = []
points_y = []
plt.axis([-10, 10, -10, 10])
for i in range(-10, 11):
    points_x.append(i)
    point=[i]
    coord = coordonate_type(*point)
    points_y.append(my_lib.predict_linear_model_regression(native_arr,coord ,arr_size,inputs_len))

plt.scatter(points_x, points_y)
plt.scatter(dataset_inputs, dataset_expected_outputs, c="purple")
plt.show()



my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

d=[1,3,1]

#Convert array to list
dataset_inputs  = toList(X)
dataset_expected_outputs  = Y.tolist()
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)

#Declaration of argtypes and restypes for the function create_mlp_model
arr_size = len(d)
arr_type = c_int * arr_size
native_arr = arr_type(*d)
my_lib.create_mlp_model.argtypes = [arr_type, c_int]
my_lib.create_mlp_model.restype = c_void_p

#creation of the model
model = my_lib.create_mlp_model(native_arr,arr_size)
test_dataset_inputs = [i for i in range(-10, 11)]

#declaration of the predict
f = c_float * 1
my_lib.predict_mlp_model_regression.argtypes = [c_void_p, f,c_int]
my_lib.predict_mlp_model_regression.restype = POINTER(c_float)
coordinate_len =1

#get the predicted outputs without training
predicted_outputs = [my_lib.predict_mlp_model_regression(model, f(*[point]), 1)[0] for point in test_dataset_inputs]

#plot the result
plt.plot(test_dataset_inputs, predicted_outputs)
plt.scatter([p for p in dataset_inputs], dataset_expected_outputs, s=200, color='purple')
plt.axis([-10, 10, -10, 10])
plt.show()


#Declaration of argtypes and restypes for the function predict_mlp_model_regression
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len
my_lib.train_regression_stochastic_backdrop_mlp_model.argtypes = [c_void_p,inputs_type,outputs_type,c_float,c_int,c_int,c_int]
my_lib.train_regression_stochastic_backdrop_mlp_model.restype = None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

my_lib.train_regression_stochastic_backdrop_mlp_model(model,inputs_native,outputs_native,0.001,100000,inputs_len,expected_len)


predicted_outputs = [my_lib.predict_mlp_model_regression(model, f(*[point]), 1)[0] for point in test_dataset_inputs]

plt.plot(test_dataset_inputs, predicted_outputs)
plt.scatter([p for p in dataset_inputs], dataset_expected_outputs, s=200, color='purple')
plt.axis([-10, 10, -10, 10])
plt.show()

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Simple 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

# %% [markdown]
# #### Linear model

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

arr_size = 2
native_arr = my_lib.create_model(arr_size)

arr_size += 1

inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordinate_type = c_float * 2
my_lib.predict_linear_model_regression.argtypes = [arr_type, coordinate_type, c_int,c_int]
my_lib.predict_linear_model_regression.restype = c_float


plt.axis([-10, 10, -10, 10])
test_dataset = [[i,j] for i in range (-5,6) for j in range(-5,6)]
predicted_outputs = [my_lib.predict_linear_model_regression(native_arr,coordinate_type(*point),arr_size,len(point)) for point in test_dataset]
test_dataset = np.array(test_dataset)
ax.scatter(X[:,0],X[:,1],Y,c='purple')
ax.scatter(test_dataset[:,0], test_dataset[:,1], predicted_outputs)


my_lib.train_regression_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_int, c_int, c_int, c_int]
my_lib.train_regression_linear_model.restype =None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)
inputs_dim = len(X[0])
outputs_dim = 1


my_lib.train_regression_linear_model(native_arr, inputs_native, outputs_native, arr_size,inputs_len,expected_len, inputs_dim, outputs_dim)


predicted_outputs = [my_lib.predict_linear_model_regression(native_arr,coordinate_type(*point),arr_size,len(point)) for point in test_dataset]

fig = plt.figure()
ax2 = Axes3D(fig)
ax2.scatter(X[:,0],X[:,1],Y,c='purple')
ax2.scatter(test_dataset[:,0], test_dataset[:,1], predicted_outputs)



my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

d = [2,1]
d_len = len(d)
d_type = c_int * d_len
my_lib.create_mlp_model.argtypes = [d_type,c_int]
my_lib.create_mlp_model.restype = c_void_p

model = my_lib.create_mlp_model(d_type(*d),d_len)
sample_inputs_len = 2
sample_inputs_type = c_float * sample_inputs_len

my_lib.predict_mlp_model_regression.argtypes = [c_void_p,sample_inputs_type, c_int]
my_lib.predict_mlp_model_regression.restype = POINTER(c_float)

test_dataset_inputs = [[i,j] for i in range(-5, 6) for j in range(-5,6)]

predicted_outputs = [my_lib.predict_mlp_model_regression(model, sample_inputs_type(*p), sample_inputs_len)[0] for p in test_dataset_inputs]

test_dataset_inputs = np.array(test_dataset_inputs)
 
ax.scatter(test_dataset_inputs[:,0],test_dataset_inputs[:,1],predicted_outputs)
ax.scatter(X[:,0],X[:,1],Y, c='purple')

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

dataset_inputs_len = len(dataset_inputs)
dataset_expected_outputs_len = len(dataset_expected_outputs)

dataset_inputs_type = c_float * dataset_inputs_len
dataset_outputs_type = c_float * dataset_expected_outputs_len

my_lib.train_regression_stochastic_backdrop_mlp_model.argtypes = [c_void_p, dataset_inputs_type, dataset_outputs_type, c_float, c_int, c_int, c_int]
my_lib.train_regression_stochastic_backdrop_mlp_model.restype = None

my_lib.train_regression_stochastic_backdrop_mlp_model(model, dataset_inputs_type(*dataset_inputs), dataset_outputs_type(*dataset_expected_outputs), 0.001, 100000, dataset_inputs_len, dataset_expected_outputs_len)

fig = plt.figure()
ax2 = Axes3D(fig)
predicted_outputs = [my_lib.predict_mlp_model_regression(model, sample_inputs_type(*p), sample_inputs_len)[0] for p in test_dataset_inputs]

ax2.scatter(test_dataset_inputs[:,0],test_dataset_inputs[:,1],predicted_outputs)
ax2.scatter(X[:,0],X[:,1],Y, c='purple')

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Tricky 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %% [markdown]
# #### Linear model

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

X = np.array([
      [1,1],
      [2,2],
      [3,3]
])
Y = np.array([
      1,
      2,
      3
])


dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

arr_size = 2
native_arr = my_lib.create_model(arr_size)

arr_size += 1

inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)
arr_type = type(native_arr)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len

#Declaration of argtypes and restypes for the function predict_linear_model_classification
coordinate_type = c_float * 2
my_lib.predict_linear_model_regression.argtypes = [arr_type, coordinate_type, c_int,c_int]
my_lib.predict_linear_model_regression.restype = c_float


plt.axis([-10, 10, -10, 10])
test_dataset = [[i,i] for i in range (-10,11)]
predicted_outputs = [my_lib.predict_linear_model_regression(native_arr,coordinate_type(*point),arr_size,len(point)) for point in test_dataset]
test_dataset = np.array(test_dataset)
ax.scatter(X[:,0],X[:,1],Y,c='purple')
ax.scatter(test_dataset[:,0], test_dataset[:,1], predicted_outputs)


my_lib.train_regression_linear_model.argtypes = [arr_type, inputs_type, outputs_type, c_int, c_int, c_int, c_int, c_int]
my_lib.train_regression_linear_model.restype =None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)
inputs_dim = len(X[0])
outputs_dim = 1


my_lib.train_regression_linear_model(native_arr, inputs_native, outputs_native, arr_size,inputs_len,expected_len, inputs_dim, outputs_dim)


predicted_outputs = [my_lib.predict_linear_model_regression(native_arr,coordinate_type(*point),arr_size,len(point)) for point in test_dataset]

fig = plt.figure()
ax2 = Axes3D(fig)
ax2.scatter(X[:,0],X[:,1],Y,c='purple')
ax2.scatter(test_dataset[:,0], test_dataset[:,1], predicted_outputs)



my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(native_arr, arr_size)

# %% [markdown]
# #### MLP

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

X = np.array([
      [1,1],
      [2,2],
      [3,3]
])
Y = np.array([
      1,
      2,
      3
])

d = [2,1]
d_len = len(d)
d_type = c_int * d_len
my_lib.create_mlp_model.argtypes = [d_type,c_int]
my_lib.create_mlp_model.restype = c_void_p

model = my_lib.create_mlp_model(d_type(*d),d_len)
sample_inputs_len = 2
sample_inputs_type = c_float * sample_inputs_len

my_lib.predict_mlp_model_regression.argtypes = [c_void_p,sample_inputs_type, c_int]
my_lib.predict_mlp_model_regression.restype = POINTER(c_float)

test_dataset_inputs = [[i,i] for i in range(-5, 6)]

predicted_outputs = [my_lib.predict_mlp_model_regression(model, sample_inputs_type(*p), sample_inputs_len)[0] for p in test_dataset_inputs]

test_dataset_inputs = np.array(test_dataset_inputs)
 
ax.scatter(test_dataset_inputs[:,0],test_dataset_inputs[:,1],predicted_outputs)
ax.scatter(X[:,0],X[:,1],Y, c='purple')

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

dataset_inputs_len = len(dataset_inputs)
dataset_expected_outputs_len = len(dataset_expected_outputs)

dataset_inputs_type = c_float * dataset_inputs_len
dataset_outputs_type = c_float * dataset_expected_outputs_len

my_lib.train_regression_stochastic_backdrop_mlp_model.argtypes = [c_void_p, dataset_inputs_type, dataset_outputs_type, c_float, c_int, c_int, c_int]
my_lib.train_regression_stochastic_backdrop_mlp_model.restype = None

my_lib.train_regression_stochastic_backdrop_mlp_model(model, dataset_inputs_type(*dataset_inputs), dataset_outputs_type(*dataset_expected_outputs), 0.001, 100000, dataset_inputs_len, dataset_expected_outputs_len)

fig = plt.figure()
ax2 = Axes3D(fig)
predicted_outputs = [my_lib.predict_mlp_model_regression(model, sample_inputs_type(*p), sample_inputs_len)[0] for p in test_dataset_inputs]

ax2.scatter(test_dataset_inputs[:,0],test_dataset_inputs[:,1],predicted_outputs)
ax2.scatter(X[:,0],X[:,1],Y, c='purple')

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 3D :
#         Linear Model       : KO
#         MLP (2, 2, 1)      : OK

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

# %% [markdown]
# #### Linear model

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

my_lib.create_model.argtypes = [c_int]
my_lib.create_model.restype = POINTER(c_float)

arr_size = 2
model = my_lib.create_model(2)

arr_size += 1
inputs_len = len(dataset_inputs)
expected_len = len(dataset_expected_outputs)
model_type = type(model)
inputs_type = c_float * inputs_len
outputs_type = c_float * expected_len

#Declaration of argtypes and restypes for the function predict_linear_model_regression
coordinate_type = c_float * 2
my_lib.predict_linear_model_regression.argtypes = [model_type, coordinate_type, c_int,c_int]
my_lib.predict_linear_model_regression.restype = c_float

test_dataset = [[i,j] for i in (-2,3) for j in (-2,3)]
predicted_outputs = [my_lib.predict_linear_model_regression(model,coordinate_type(*p), arr_size, len(p)) for p in test_dataset]

test_dataset = np.array(test_dataset)
ax.scatter(X[:,0],X[:,1],Y, c='purple')
ax.scatter(test_dataset[:,0],test_dataset[:,1],predicted_outputs)
plt.show()
plt.clf()

my_lib.train_regression_linear_model.argtypes = [model_type, inputs_type, outputs_type, c_int, c_int, c_int,c_int, c_int]
my_lib.train_regression_linear_model.restype =None
inputs_native = inputs_type(*dataset_inputs)
outputs_native = outputs_type(*dataset_expected_outputs)

input_dim = len(X[0])
output_dim = 1

my_lib.train_regression_linear_model(model, inputs_native, outputs_native, arr_size,inputs_len,expected_len, input_dim, output_dim)

fig = plt.figure()
ax2 = Axes3D(fig)
ax2.scatter(X[:,0],X[:,1],Y,c='purple')
predicted_outputs = [my_lib.predict_linear_model_regression(model,coordinate_type(*p), arr_size, len(p)) for p in test_dataset]

ax2.scatter(test_dataset[:,0],test_dataset[:,1],predicted_outputs)
plt.show()
plt.clf()

my_lib.destroy_array.argtypes = [POINTER(c_float), c_int]
my_lib.destroy_array.restype = None
my_lib.destroy_array(model, arr_size)

# %% [markdown]
# #### MLP

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

d = [2,2,1]
d_len = len(d)
d_type = c_int * d_len
my_lib.create_mlp_model.argtypes = [d_type,c_int]
my_lib.create_mlp_model.restype = c_void_p

model = my_lib.create_mlp_model(d_type(*d),d_len)
sample_inputs_len = 2
sample_inputs_type = c_float * sample_inputs_len

my_lib.predict_mlp_model_regression.argtypes = [c_void_p,sample_inputs_type, c_int]
my_lib.predict_mlp_model_regression.restype = POINTER(c_float)

test_dataset_inputs = [[i,j] for i in range(-5, 6) for j in range(-5,6)]

predicted_outputs = [my_lib.predict_mlp_model_regression(model, sample_inputs_type(*p), sample_inputs_len)[0] for p in test_dataset_inputs]

test_dataset_inputs = np.array(test_dataset_inputs)
 
ax.scatter(test_dataset_inputs[:,0],test_dataset_inputs[:,1],predicted_outputs)
ax.scatter(X[:,0],X[:,1],Y, c='purple')

dataset_inputs = toList(X)
dataset_expected_outputs = Y.tolist()

dataset_inputs_len = len(dataset_inputs)
dataset_expected_outputs_len = len(dataset_expected_outputs)

dataset_inputs_type = c_float * dataset_inputs_len
dataset_outputs_type = c_float * dataset_expected_outputs_len

my_lib.train_regression_stochastic_backdrop_mlp_model.argtypes = [c_void_p, dataset_inputs_type, dataset_outputs_type, c_float, c_int, c_int, c_int]
my_lib.train_regression_stochastic_backdrop_mlp_model.restype = None

my_lib.train_regression_stochastic_backdrop_mlp_model(model, dataset_inputs_type(*dataset_inputs), dataset_outputs_type(*dataset_expected_outputs), 0.001, 100000, dataset_inputs_len, dataset_expected_outputs_len)

fig = plt.figure()
ax2 = Axes3D(fig)
predicted_outputs = [my_lib.predict_mlp_model_regression(model, sample_inputs_type(*p), sample_inputs_len)[0] for p in test_dataset_inputs]

ax2.scatter(test_dataset_inputs[:,0],test_dataset_inputs[:,1],predicted_outputs)
ax2.scatter(X[:,0],X[:,1],Y, c='purple')

#Free memory
my_lib.destroy_model.argtypes = [c_void_p]
my_lib.destroy_model.restype = None
my_lib.destroy_model(model)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()
